# %% [markdown]
# #Data Science Capstone Project
#
# ##Introduction/Business Problem
#
# In this project, we will explore the central area of Toronto and suggest best regions to people who is looking to open a Turkish restaurant in central Toronto.
# The Foursquare location data will be used to explore neighbourhoods in Toronto and find out insights such as which neighbourhoods are popular for Turkish.
#
# The assumption here in this project is that the stakeholders are interested to open a Turkish restaurant in neighbourhoods which are already famous/popular for Turkish food.
#
#
#
# First of all , we need a list of neighbourhoods in Toronto before querying.
# I will use the list of neighbourhoods available on wikipedia page and filter out the central neighbourhoods.
# --https://tr.wikipedia.org/wiki/Toronto
#
#
# After that, with the list of regions, I will get the latitudes and longitudes of the neighbourhoods with geocoder.
#
# With the latitudes and longitudes of the neighbourhoods, I can then query Foursquare to explore the popularity of Thai food in the neighbourhood.
# The rank of Turkish restaurant among all pupular venues near each neighbourhood will be gathered and compared.
# The number of Turkish restaurants in the neighbourhood will also be queried to provide more insights.
